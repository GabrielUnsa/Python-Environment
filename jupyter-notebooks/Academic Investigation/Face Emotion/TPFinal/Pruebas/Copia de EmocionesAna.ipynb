# %% [markdown]
# 0 - 180
# 1 - 72
# 2 - 236
# 3 - 100
# 4 - 276
# 5 - 112
# 6 - 332

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/TPFinal

# List files to make sure we're in the expected directory.
# Your output will look different, showing your own Drive files here.
# !ls
# !ls -l image2feature.py

import image2feature as i2f
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/TPFinal
# 'Copia de EmocionesAna.ipynb'   EmocionesWalter.ipynb	 __pycache__
#  dataset.py		        image2feature.py	 X_train0.pkl.gz
#  dataset.txt		        image2feature.pyc	 X_train2.pkl.gz
#  EmocionesAna.ipynb	        ImportarArchivos.ipynb	 X_train4.pkl.gz
# -rw------- 1 root root 896 Jun 13 14:30 image2feature.py
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/TPFinal

# List files to make sure we're in the expected directory.
# Your output will look different, showing your own Drive files here.
# !ls
# !ls -l image2feature.py

import image2feature as i2f
import numpy as np
import cv2
import re
from pathlib import Path
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import pickle
import gc 
import gzip


def ls(ruta = Path.cwd()):
    return [arch.name for arch in Path(ruta).iterdir() if arch.is_file()]

X_train, y_train = list(), list()
X_test, y_test = list(), list()

preproc = i2f.Extractor()
#X_train = list()
#with open("/content/drive/My Drive/TPFinal/dataset.txt","r") as file:
 #   line = file.readline()
  #  while ( line != '' ):
   #   if( 'S026' in line ):
        
ruta  = "/content/drive/My Drive/Cohn-kanade-dataset/S026/003/"
lista = ls( ruta )
#y_train.append( int(0) )
#y_test.append( int(0) )
for i in range(len(lista)-5 , len(lista) ):
  if( i != len(lista)-1 ):
    X_train.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(0) )
    y_test.append( int(0) )
  else: 
    X_test.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(0) )
    y_test.append( int(0) )

ruta  = "/content/drive/My Drive/Cohn-kanade-dataset/S026/006/"
lista = ls( ruta )
#y_train.append( int(4) )
#y_test.append( int(4) )
for i in range(len(lista)-5 , len(lista) ):
  if( i != len(lista)-1 ):
    X_train.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(4) )
    y_test.append( int(4) )
  else: 
    X_test.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(4) )
    y_test.append( int(4) )
    
ruta  = "/content/drive/My Drive/Cohn-kanade-dataset/S026/002/"
lista = ls( ruta )
#y_train.append( int(5) )
#y_test.append( int(5) )
for i in range(len(lista)-5 , len(lista) ):
  if( i != len(lista)-1 ):
    X_train.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(5) )
    y_test.append( int(5) )
  else: 
    X_test.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(5) )
    y_test.append( int(5) )

ruta  = "/content/drive/My Drive/Cohn-kanade-dataset/S026/001/"
lista = ls( ruta )

for i in range(len(lista)-5 , len(lista) ):
  if( i != len(lista)-1 ):
    X_train.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(6) )
    y_test.append( int(6) )
  else: 
    X_test.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
    y_train.append( int(6) )
    y_test.append( int(6) )
        
X_train, y_train = np.array(X_train), np_utils.to_categorical(y_train)  
#with gzip.open("/content/drive/My Drive/TPFinal/X_t.pkl.gz","wb") as of:
	#pickle.dump((X_train, y_train),of, pickle.HIGHEST_PROTOCOL)

X_test, y_test = np.array(X_test), np_utils.to_categorical(y_test)  
#with gzip.open("/content/drive/My Drive/TPFinal/X_te.pkl.gz","wb") as of:
	#pickle.dump((X_test, y_test),of, pickle.HIGHEST_PROTOCOL)
#X_train, y_train = np.array(X_train), np_utils.to_categorical(y_train)  
        
#with gzip.open("/content/drive/My Drive/Colab Notebooks/TPFinal/train.pkl.gz","wb") as of:
#	pickle.dump((X_train,y_train),of, pickle.HIGHEST_PROTOCOL)

gc.collect()
print(X_test)
print("Len " + str(len(X_test)))
print(y_test)
print("Len " + str(len(y_test)))
print("fin")

model = Sequential()
model.add( Dense( 10000, input_dim = 25088, activation = 'relu' ) )
model.add(Dense(5000, activation='relu'))
model.add(Dense(7, activation='relu'))
epocas = 10
lrate = 0.001
decay = lrate/epocas
sgd = SGD( lr = lrate, momentum = 0.9, decay = decay, nesterov = False )
model.compile( loss = 'categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'] )
model.fit(X_train, y_train, epochs = epocas, batch_size = 1 )
#scores = model.evaluate( X_test, y_test )
#print( "\n%s: %.2f%%" % ( model.metrics_names[1], scores[1]*100 ) )

# model = Sequential()
# model.add( Dense( 50, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 75, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 50, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 7, activation = 'sigmoid' ) )
#
# epocas = 100
# lrate = 0.01
# decay = lrate/epocas
# sgd = SGD( lr = lrate, momentum = 0.9, decay = decay, nesterov = False )
#
# model.compile( loss = 'binary_crossentropy', optimizer = sgd, metrics=['accuracy'] )
# f.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/TPFinal
# 'Copia de EmocionesAna.ipynb'   ImportarArchivos.ipynb	 X_train2.pkl.gz
#  dataset.py		        __pycache__		 X_train3.pkl.gz
#  dataset.txt		        test0-3.pkl.gz		 X_train4.pkl.gz
#  EmocionesAna.ipynb	        test3-7.pkl.gz		 X_train5.pkl.gz
#  EmocionesWalter.ipynb	        test4-6.pkl.gz		 X_train6.pkl.gz
#  image2feature.py	        X_train0.pkl.gz		 y_test.pkl.gz
#  image2feature.pyc	        X_train1.pkl.gz		 y_train.pkl.gz
# -rw------- 1 root root 896 Jun 13 14:30 image2feature.py
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
# ...

# %%
import numpy as np
import cv2
import re
from pathlib import Path
from keras.utils import np_utils
import pickle
import gc 
import gzip


def ls(ruta = Path.cwd()):
    return [arch.name for arch in Path(ruta).iterdir() if arch.is_file()]

X_train, y_train = list(), list()
#X_train = list()
with open("/content/drive/My Drive/TPFinal/dataset.txt","r") as file:
  line = file.readline()
  while ( line != '' ):
    preproc = i2f.Extractor()
    ruta  = "/content/drive/My Drive/Cohn-kanade-dataset/"+str(line[:4])+'/'+str(line[5:8])+'/'
    if ( (int) (line[9:]) == 3 ): #Emocion
      lista = ls( ruta )
      y_train.append( line[9:] )
      for i in range(len(lista)-5 , len(lista) ):
      if( i != len(lista)-1 ):
                X_train.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
        line = file.readline()
        gc.collect() 
X_train, y_train = np.array(X_train), np_utils.to_categorical(y_train)  
with gzip.open("/content/drive/My Drive/TPFinal/X_train3.pkl.gz","wb") as of:
	pickle.dump((X_train),of, pickle.HIGHEST_PROTOCOL)

#X_train, y_train = np.array(X_train), np_utils.to_categorical(y_train)  
        
#with gzip.open("/content/drive/My Drive/Colab Notebooks/TPFinal/train.pkl.gz","wb") as of:
#	pickle.dump((X_train,y_train),of, pickle.HIGHEST_PROTOCOL)



# model = Sequential()
# model.add( Dense( 50, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 75, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 50, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 7, activation = 'sigmoid' ) )
#
# epocas = 100
# lrate = 0.01
# decay = lrate/epocas
# sgd = SGD( lr = lrate, momentum = 0.9, decay = decay, nesterov = False )
#
# model.compile( loss = 'binary_crossentropy', optimizer = sgd, metrics=['accuracy'] )
# f.close()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0614 22:27:17.666882 140160552449920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0614 22:27:17.694235 140160552449920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0614 22:27:17.704004 140160552449920 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/TPFinal

# List files to make sure we're in the expected directory.
# Your output will look different, showing your own Drive files here.
# !ls
#!ls -l image2feature.py

#import image2feature as i2f
import numpy as np
import cv2
import re
from pathlib import Path
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import pickle
import gc 
import gzip
from keras.applications import vgg16
def resize_data(data):  
    data_upscaled = np.zeros((data.shape[0], 224, 224, 224))
    for i, img in enumerate(data):
        large_img = cv2.resize(img, dsize=( 224, 224), interpolation=cv2.INTER_CUBIC)
        data_upscaled[i] = large_img

    return data_upscaled
def create_vgg16():  
  model = vgg16.VGG16(include_top=False, weights='imagenet', input_tensor=None, input_shape=(224,224,3), pooling=None, classes=7)
  return model
def ls(ruta = Path.cwd()):
  return [arch.name for arch in Path(ruta).iterdir() if arch.is_file()]

X_train, y_train = list(), list()
X_test, y_test = list(), list()
#X_train = list()
with open("/content/drive/My Drive/TPFinal/dataset.txt","r") as file:
  line = file.readline()
  while ( line != '' ):
    if( line[:4] == "S026"):
      #preproc = i2f.Extractor()
      ruta  = "/content/drive/My Drive/Cohn-kanade-dataset/S026/"+str(line[5:8])+'/'
      lista = ls( ruta )
      #y_train.append( line[9:] )
      for i in range(len(lista)-5 , len(lista) ):
        if( i != len(lista)-1 ):
          X_train.append(resize_data(cv2.imread(ruta + lista[i])))
          #X_train.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
          y_train.append( line[9:] )
          print(X_train)
        else: 
          X_test.append(resize_data(cv2.imread(ruta + lista[i])))
          #X_test.append( preproc.extract( cv2.imread( ruta + lista[i] ) ) )
          y_test.append( line[9:] )
    line = file.readline()
gc.collect() 
X_train, y_train = np.array(X_train/255), np_utils.to_categorical(y_train)  
X_test, y_test = np.array(X_test/255), np_utils.to_categorical(y_test)  
print(X_train)

vgg16_model = create_vgg16()  
vgg16_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['acc', 'mse']) 
vgg16 = vgg16_model.fit(x=X_train, y=y_train, batch_size=1, epochs=10, verbose=0, validation_data=(x_test_resized, y_test), shuffle=True) 

'''with gzip.open("/content/drive/My Drive/TPFinal/trS026.pkl.gz","wb") as of:
  pickle.dump((X_train,y_train),of, pickle.HIGHEST_PROTOCOL)
with gzip.open("/content/drive/My Drive/TPFinal/teS026.pkl.gz","wb") as of:
  pickle.dump((X_test,y_test),of, pickle.HIGHEST_PROTOCOL)
'''  
#print( str(len(X_train)) + str(len(y_train)) )
#print( str(len(X_test)) + str(len(y_test)) )
'''
f = gzip.open("/content/drive/My Drive/TPFinal/trS026.pkl.gz","rb")
X_train, y_train = pickle.load(f)
f.close()
f = gzip.open("/content/drive/My Drive/TPFinal/teS026.pkl.gz","rb")
X_test, y_test = pickle.load(f)
f.close() '''
#print( str(len(X_train)) + " " + str(len(y_train)) )
#print( str(len(X_test)) + " " + str(len(y_test)) )
gc.collect()
'''model = Sequential()
model.add( Dense( 1000, input_dim = 25088, activation = 'relu' ) )
#model.add(Dense(1000, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
epocas = 20
lrate = 0.01
decay = lrate/epocas
sgd = SGD( lr = lrate, momentum = 0.9, decay = decay, nesterov = True )
model.compile( loss = 'categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'] )
model.fit(X_train, y_train, epochs = epocas, batch_size = 1 )

pre = model.predict_classes(X_test, verbose=0)
print(pre)'''
#scores = model.evaluate( X_test, y_test )
#print( "\n%s: %.2f%%" % ( model.metrics_names[1], scores[1]*100 ) )

#with gzip.open("/content/drive/My Drive/TPFinal/X_train3.pkl.gz","wb") as of:
	#pickle.dump((X_train),of, pickle.HIGHEST_PROTOCOL)

#X_train, y_train = np.array(X_train), np_utils.to_categorical(y_train)  
        
#with gzip.open("/content/drive/My Drive/TPFinal/train.pkl.gz","wb") as of:
#	pickle.dump((X_train,y_train),of, pickle.HIGHEST_PROTOCOL)

# model = Sequential()
# model.add( Dense( 50, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 75, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 50, input_dim = len(x_train[0]), activation = 'relu' ) )
# model.add( Dense( 7, activation = 'sigmoid' ) )
#
# epocas = 100
# lrate = 0.01
# decay = lrate/epocas
# sgd = SGD( lr = lrate, momentum = 0.9, decay = decay, nesterov = False )
#
# model.compile( loss = 'binary_crossentropy', optimizer = sgd, metrics=['accuracy'] )
# f.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/TPFinal
# 'Copia de EmocionesAna.ipynb'   __pycache__	  X_train2.pkl.gz
#  dataset.py		        teS026.pkl.gz	  X_train3.pkl.gz
#  dataset.txt		        test0-3.pkl.gz	  X_train4.pkl.gz
#  EmocionesAna.ipynb	        test3-7.pkl.gz	  X_train5.pkl.gz
#  EmocionesWalter.ipynb	        test4-6.pkl.gz	  X_train6.pkl.gz
#  image2feature.py	        trS026.pkl.gz	  y_test.pkl.gz
#  image2feature.pyc	        X_train0.pkl.gz   y_train.pkl.gz
#  ImportarArchivos.ipynb         X_train1.pkl.gz
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/TPFinal

# List files to make sure we're in the expected directory.
# Your output will look different, showing your own Drive files here.
#!ls
#!ls -l image2feature.py

import image2feature as i2f
import numpy as np
import cv2
import re
from pathlib import Path
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import pickle
import gc 
import gzip
from keras.layers import Convolution2D, MaxPooling2D, Dropout
from keras.layers import Flatten, Dense

f = gzip.open("/content/drive/My Drive/TPFinal/trS026.pkl.gz","rb")
X_train, y_train = pickle.load(f)
f.close()
f = gzip.open("/content/drive/My Drive/TPFinal/teS026.pkl.gz","rb")
X_test, y_test = pickle.load(f)
f.close()
#print( str(len(X_train)) + " " + str(len(y_train)) )
#print( str(len(X_test)) + " " + str(len(y_test)) )
gc.collect()

# Your model should accept 96x96 pixel graysale images in
# It should have a fully-connected output layer with 30 values (2 for each facial keypoint)
shape = ( 224, 224 )
model = Sequential()
model.add(Convolution2D(16,(2,2),padding='same',input_shape=(224,224, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=3))

model.add(Convolution2D(32,(3,3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=3))
model.add(Dropout(0.2))

model.add(Convolution2D(64,(3,3),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=3))
model.add(Dropout(0.2))

model.add(Convolution2D(128,(3,3),padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=3))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(7, activation='softmax'))

# Summarize the model
model.summary()

epocas = 10
lrate = 0.01
decay = lrate/epocas
sgd = SGD( lr = lrate, momentum = 0.9, decay = decay, nesterov = False )
model.compile( loss = 'categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'] )
model.fit(X_train, y_train, epochs = epocas, batch_size = 1 )

pre = model.predict_classes(X_test, verbose=0)
print(pre)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/TPFinal
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-100c55b70ac7> in <module>()
#      37 shape = ( 224, 224 )
#      38 model = Sequential()
# ---> 39 model.add(Convolution2D(16,(2,2),padding='same',input_dim = 25088, activation='relu'))
#      40 model.add(MaxPooling2D(pool_size=3))
#      41
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ...
