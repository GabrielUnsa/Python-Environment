# %% [markdown]
# Importar archivos dentro del mismo drive
#
# https://colab.research.google.com/drive/12qC2abKAIAlUM_jNAokGlooKY-idbSxi#scrollTo=uSOOYNBkCkD8

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/Colab Notebooks/TPFinal

# List files to make sure we're in the expected directory.
# Your output will look different, showing your own Drive files here.
# !ls
# !ls -l image2feature.py

import image2feature
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/TPFinal
# dataset.py   image2feature.py	     TPFinal.ipynb
# dataset.txt  ImportarArchivos.ipynb
# -rw------- 1 root root 896 Jun 13 14:30 image2feature.py
# Using TensorFlow backend.

# %% [markdown]
# Importar modulos
# https://www.pingshiuanchua.com/blog/post/importing-your-own-python-module-or-python-file-in-colaboratory

# %%
# !pip install import-ipynb
# !pip install -U -q PyDrive

# %%
 #Autentificamos el Acceso
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
your_module = drive.CreateFile({'id':'https://drive.google.com/open?id=1lxFPuGGSAQll3bXT-xsBvCB0zCg8SG_O'})
your_module.GetContentFile('name.py')
